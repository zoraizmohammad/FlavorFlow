# %% [markdown]
# <a href="https://colab.research.google.com/github/zoraizmohammad/FlavorFlow/blob/main/data/dataProcessingMicro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Processing**

# %% [markdown]
# **Data Insertion**

# %% [markdown]
# View Tasks here: https://github.com/zoraizmohammad/FlavorFlow/blob/main/weeklyTasks/week2.md#to-complete-step-1-data-collection-and-preparation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install quantulum3
# Out:
# Collecting quantulum3
#   Downloading quantulum3-0.9.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from quantulum3) (7.4.0)
# Collecting num2words (from quantulum3)
#   Downloading num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: more-itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect->quantulum3) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect->quantulum3) (4.4.1)
# Collecting docopt>=0.6.2 (from num2words->quantulum3)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from typeguard>=4.0.1->inflect->quantulum3) (4.12.2)
# Downloading quantulum3-0.9.2-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 84.8 MB/s eta 0:00:00
# Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 12.6 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=7522352ce04678a2fc6d05c049b6b91baf0223b958163034c5a5f9f316613039
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# Installing collected packages: docopt, num2words, quantulum3
# Successfully installed docopt-0.6.2 num2words-0.5.13 quantulum3-0.9.2

# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
#RUN - Has all imports
import pandas as pd
import nltk
from nltk.corpus import words, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from quantulum3 import parser
from fuzzywuzzy import fuzz, process
import re
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def view(file_path, num_columns):
  df = pd.read_csv(file_path)
  print(df.iloc[:, :num_columns])

# %%
raw_annotation = pd.read_csv('/content/drive/MyDrive/FlavorFlow/Data/full_dataset.csv')
# Based on who's using copy and paste in path. Refrence:
# RP MZ: /content/drive/MyDrive/FlavorSync/Data/full_dataset.csv
# RP GM:
# RP RM:

# %%
raw_annotation
# Out:
#          Unnamed: 0                                          title  \
# 0                 0                            No-Bake Nut Cookies
# 1                 1                          Jewell Ball'S Chicken
# 2                 2                                    Creamy Corn
# 3                 3                                  Chicken Funny
# 4                 4                           Reeses Cups(Candy)
# ...             ...                                            ...
# 2231137     2231137                            Sunny's Fake Crepes
# 2231138     2231138                                     Devil Eggs
# 2231139     2231139  Extremely Easy and Quick - Namul Daikon Salad
# 2231140     2231140     Pan-Roasted Pork Chops With Apple Fritters
# 2231141     2231141                 Polpette in Spicy Tomato Sauce
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# ...                                                    ...
# 2231137  ["1/2 cup chocolate hazelnut spread (recommend...
# 2231138  ["1 dozen eggs", "1 paprika", "1 salt and pepp...
# 2231139  ["150 grams Daikon radish", "1 tbsp Sesame oil...
# 2231140  ["1 cup apple cider", "6 tablespoons sugar", "...
# 2231141  ["1 pound ground veal", "1/2 pound sweet Itali...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 2        ["In a slow cooker, combine all ingredients. C...
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# ...                                                    ...
# 2231137  ["Spread hazelnut spread on 1 side of each tor...
# 2231138  ["Boil eggs on medium for 30mins.", "Then cool...
# 2231139  ["Julienne the daikon and squeeze out the exce...
# 2231140  ["In a large bowl, mix the apple cider with 4 ...
# 2231141  ["Preheat the oven to 350.", "In a bowl, mix t...
#
#                                                       link     source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874   Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419   Gathered
# 2           www.cookbooks.com/Recipe-Details.aspx?id=10570   Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570   Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239   Gathered
# ...                                                    ...        ...
# 2231137  www.foodnetwork.com/recipes/sunny-anderson/sun...  Recipes1M
# 2231138           cookpad.com/us/recipes/355411-devil-eggs  Recipes1M
# 2231139  cookpad.com/us/recipes/153324-extremely-easy-a...  Recipes1M
# 2231140                cooking.nytimes.com/recipes/1015164  Recipes1M
# 2231141  www.foodandwine.com/recipes/polpette-spicy-tom...  Recipes1M
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 2        ["frozen corn", "cream cheese", "butter", "gar...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# ...                                                    ...
# 2231137  ["chocolate hazelnut spread", "tortillas", "bu...
# 2231138  ["eggs", "paprika", "salt", "choice", "miracle...
# 2231139  ["radish", "Sesame oil", "White sesame seeds",...
# 2231140  ["apple cider", "sugar", "kosher salt", "bay l...
# 2231141  ["ground veal", "sausage", "bread crumbs", "mi...
#
# [2231142 rows x 7 columns]

# %% [markdown]
# ### **Micro-Dataset Creation**

# %%
import pandas as pd

# Read the full dataset
raw_annotation = pd.read_csv('/content/drive/MyDrive/FlavorFlow/Data/full_dataset.csv')

# Select only the first 10,000 rows
first_10000 = raw_annotation.head(10000)

# Save the new data to a CSV file
first_10000.to_csv('/content/drive/MyDrive/FlavorFlow/Data/first_10000_rows.csv', index=False)

# %% [markdown]
# ## **Data Cleaning & Export**

# %%
# !pip install stemming
# !pip install scikit-learn==1.5.0
# Out:
# Collecting stemming
#   Downloading stemming-1.0.1.zip (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: stemming
#   Building wheel for stemming (setup.py) ... done
#   Created wheel for stemming: filename=stemming-1.0.1-py3-none-any.whl size=11123 sha256=9b184f28a5fb8a23a9ca9857477416f1eb2c15a250fc7d0738581fd7230dec8a
#   Stored in directory: /root/.cache/pip/wheels/c5/f9/3f/8fe1ec182ce66145d7ded39bad9a690960469dc350fbec0181
# Successfully built stemming
# Installing collected packages: stemming
# Successfully installed stemming-1.0.1
# Collecting scikit-learn==1.5.0
#   Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.0) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.0) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.5.0) (3.5.0)
# Downloading scikit_learn-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 74.0 MB/s eta 0:00:00
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
# Successfully installed scikit-learn-1.5.0

# %%
# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/FlavorFlow/Data/first_10000_rows.csv')
import nltk
nltk.download('punkt')

#Remove Duplicates
# Filter by source and remove duplicate recipes
data = data[data['source'] == "Gathered"].drop_duplicates()

# Normalize Text
# Download necessary NLTK data
nltk.download('words')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Create a lemmatizer instance
lemmatizer = WordNetLemmatizer()

# Base ingredient names
base_ingredients = [
    "bell pepper", "chili", "cilantro", "eggplant", "zucchini", "potato", "tomato",
    "onion", "garlic", "carrot", "mushroom", "cabbage", "lettuce", "spinach"
]

# Ingredient mapping dictionary
ingredient_mapping = {ingredient: ingredient for ingredient in base_ingredients}

# Function to automate ingredient mapping using fuzzy matching
def create_ingredient_mapping(ingredient_list, base_ingredients, threshold=80):
    for ingredient in ingredient_list:
        # Find the best match from the base ingredients using fuzzy matching
        match, score = process.extractOne(ingredient, base_ingredients)
        if score >= threshold:  # If the similarity score is above the threshold
            ingredient_mapping[ingredient] = match

# Get a list of unique ingredients from the dataset
unique_ingredients = set()
data['ingredients'].apply(lambda x: unique_ingredients.update(word_tokenize(x.lower())))

# Generate ingredient mappings
create_ingredient_mapping(unique_ingredients, base_ingredients)

# Function to normalize ingredients
def normalize_ingredients(text):
    tokens = word_tokenize(text.lower())  # Tokenize and lowercase the text
    normalized_tokens = []

    for token in tokens:
        # Lemmatize each token and map using the ingredient dictionary
        lemmatized_word = lemmatizer.lemmatize(token)
        if lemmatized_word in ingredient_mapping:
            normalized_tokens.append(ingredient_mapping[lemmatized_word])
        else:
            normalized_tokens.append(lemmatized_word)

    return ' '.join(normalized_tokens)

# Apply normalization to the 'ingredients' column
data['ingredients'] = data['ingredients'].apply(normalize_ingredients)

#Spell-Check and Correct Typos
english_words = set(words.words())

def correct_spelling(text):
    tokens = word_tokenize(text)
    corrected_tokens = [token if token in english_words else token for token in tokens]
    return ' '.join(corrected_tokens)

# Apply spell-check to the 'directions' column
data['directions'] = data['directions'].apply(correct_spelling)

# Standardize Units
def standardize_units(text):
    quantities = parser.parse(text)
    standardized_text = " ".join([str(quantity) for quantity in quantities])
    return standardized_text

# Apply unit standardization
data['ingredients'] = data['ingredients'].apply(standardize_units)

# Save the cleaned data
data.to_csv("/content/drive/MyDrive/FlavorFlow/Data/cleaned_micro_data.csv", index=False)

data.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '``']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ']']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '''']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '%']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '!']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+/-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ')']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '\']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ';']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ''']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '(']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '*']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '--']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '[']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '?']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '#']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '&']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ':']
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  one zero point five zero point five teaspoons ...
# 1  one four one one centavo year roentgen short tons
# 2  two sixteen ounces one eight ounces zero point...
# 3  one two ten point five ounces one ten point fi...
# 4  one zero point seven five one one pound three ...
#
#                                           directions  \
# 0  [ `` In a heavy 2-quart saucepan , mix brown s...
# 1  [ `` Place chipped beef on bottom of baking di...
# 2  [ `` In a slow cooker , combine all ingredient...
# 3  [ `` Boil and debone chicken . `` , `` Put bit...
# 4  [ `` Combine first four ingredients and press ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...

# %% [markdown]
# # **Tokenize Ingredients & Steps**

# %%
# Load the cleaned data
data = pd.read_csv("/content/drive/MyDrive/FlavorFlow/Data/cleaned_micro_data.csv")

# Ensure necessary NLTK data is downloaded
nltk.download('punkt')

# Step 1: Ingredients Tokenization
def tokenize_ingredient(ingredient):
    # Regular expression to capture quantity, unit, and ingredient name
    pattern = r'(?P<quantity>\d*\.?\d+)?\s*(?P<unit>\b\w+\b)?\s*(?P<ingredient>.+)'
    match = re.match(pattern, ingredient)

    if match:
        quantity = match.group('quantity') if match.group('quantity') else None
        unit = match.group('unit') if match.group('unit') else None
        ingredient_name = match.group('ingredient').strip() if match.group('ingredient') else None
        return {'quantity': quantity, 'unit': unit, 'ingredient': ingredient_name}
    return {'quantity': None, 'unit': None, 'ingredient': ingredient}

# Apply the tokenization to the 'ingredients' column, handling NaN values
data['ingredients_tokenized'] = data['ingredients'].apply(
    lambda x: [tokenize_ingredient(ing) for ing in x.split(',')] if isinstance(x, str) else []
)


# Step 2: Steps Tokenization
# Define common cooking actions
cooking_actions = [
    "chop", "saute", "bake", "fry", "boil", "mix", "stir", "grill", "roast",
    "slice", "dice", "mince", "blend", "whisk", "season", "cook", "serve"
]

def tokenize_step(step):
    # Tokenize the step into words
    tokens = word_tokenize(step.lower())

    # Find actions and associated ingredients
    actions = [action for action in cooking_actions if action in tokens]
    related_ingredients = [token for token in tokens if token not in cooking_actions]

    return {'actions': actions, 'related_ingredients': related_ingredients}

# Apply the tokenization to the 'steps' column
data['directions_tokenized'] = data['directions'].apply(tokenize_step)

# Save the tokenized data
data.to_csv("/content/drive/MyDrive/FlavorFlow/Data/tokenized_micro_data.csv", index=False)

data.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#    Unnamed: 0                  title  \
# 0           0    No-Bake Nut Cookies
# 1           1  Jewell Ball'S Chicken
# 2           2            Creamy Corn
# 3           3          Chicken Funny
# 4           4   Reeses Cups(Candy)
#
#                                          ingredients  \
# 0  one zero point five zero point five teaspoons ...
# 1  one four one one centavo year roentgen short tons
# 2  two sixteen ounces one eight ounces zero point...
# 3  one two ten point five ounces one ten point fi...
# 4  one zero point seven five one one pound three ...
#
#                                           directions  \
# 0  [ `` In a heavy 2-quart saucepan , mix brown s...
# 1  [ `` Place chipped beef on bottom of baking di...
# 2  [ `` In a slow cooker , combine all ingredient...
# 3  [ `` Boil and debone chicken . `` , `` Put bit...
# 4  [ `` Combine first four ingredients and press ...
#
#                                               link    source  \
# 0   www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1  www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2   www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3  www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4  www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
#
#                                                  NER  \
# 0  ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1  ["beef", "chicken breasts", "cream of mushroom...
# 2  ["frozen corn", "cream cheese", "butter", "gar...
# 3  ["chicken", "chicken gravy", "cream of mushroo...
# 4  ["peanut butter", "graham cracker crumbs", "bu...
#
#                                ingredients_tokenized  \
# 0  [{'quantity': None, 'unit': 'one', 'ingredient...
# 1  [{'quantity': None, 'unit': 'one', 'ingredient...
# 2  [{'quantity': None, 'unit': 'two', 'ingredient...
# 3  [{'quantity': None, 'unit': 'one', 'ingredient...
# 4  [{'quantity': None, 'unit': 'one', 'ingredient...
#
#                                 directions_tokenized
# 0  {'actions': ['boil', 'mix', 'stir'], 'related_...
# 1  {'actions': ['bake', 'mix'], 'related_ingredie...
# 2  {'actions': ['stir', 'cook'], 'related_ingredi...
# 3  {'actions': ['bake', 'boil'], 'related_ingredi...
# 4  {'actions': [], 'related_ingredients': ['[', '...

# %% [markdown]
# # **Markov Chain State Modeling**

# %%
# Load the tokenized data
data = pd.read_csv("/content/drive/MyDrive/FlavorFlow/Data/tokenized_micro_data.csv")

# Step 1: Assign State IDs to Ingredients
# Flatten all ingredients into a single list
all_ingredients = set()
for ingredient_list in data['ingredients_tokenized']:
    ingredient_list = eval(ingredient_list)  # Convert string representation to list of dicts
    for item in ingredient_list:
        if item['ingredient']:
            all_ingredients.add(item['ingredient'])

# Create a mapping of ingredients to state IDs
ingredient_states = {ingredient: idx for idx, ingredient in enumerate(sorted(all_ingredients), start=1)}

# Step 2: Assign State IDs to Cooking Actions
# Extract all unique cooking actions from the steps
all_actions = set()
for step in data['directions_tokenized']:
    step_data = eval(step)  # Convert string representation to dict
    for action in step_data['actions']:
        all_actions.add(action)

# Create a mapping of actions to state IDs
action_states = {action: idx for idx, action in enumerate(sorted(all_actions), start=1)}

# Step 3: Create Mappings for Ingredients and Steps
# Assign state IDs to each ingredient in the 'ingredients_tokenized' column
def assign_ingredient_states(ingredient_list):
    ingredient_list = eval(ingredient_list)
    return [ingredient_states[item['ingredient']] for item in ingredient_list if item['ingredient']]

data['ingredient_states'] = data['ingredients_tokenized'].apply(assign_ingredient_states)

# Assign state IDs to each action in the 'steps_tokenized' column
def assign_action_states(step_data):
    step_data = eval(step_data)
    return [action_states[action] for action in step_data['actions']]

data['action_states'] = data['directions_tokenized'].apply(assign_action_states)

# Save the data with state IDs
data.to_csv("/content/drive/MyDrive/FlavorFlow/Data/states_micro_data.csv", index=False)

# Display the state mappings for reference
ingredient_states, action_states
# Out:
# ({'-eight two one pound one': 1,
#   '-five pounds twelve pounds fifteen pounds six thirty-two ounces six point five tablespoons one zero point five one thirteen pounds eighteen quarts twenty pints six point five tablespoons eight tablespoons': 2,
#   '-five six pounds zero point five zero point five two pounds four one pound two fourteen ounces three tablespoons two tablespoons one tablespoon two two four tablespoons five zero point two five pounds two pints': 3,
#   '-five thirty eight two zero point five five five two tablespoons one teaspoon zero point five teaspoons four five': 4,
#   '-five thirty two five one four one point five': 5,
#   '-five thirty zero point five pounds zero point two five zero point five one one one teaspoon zero point five teaspoons': 6,
#   '-five two one two zero point two five teaspoons zero point two five teaspoons': 7,
#   '-four fifteen ounces zero point two five one teaspoon one teaspoon three tablespoons': 8,
#   '-four four four six six zero point two five zero point five zero point two five two': 9,
#   '-four one six ounces four tablespoons zero point five teaspoons': 10,
#   '-four one six ounces zero point five one one teaspoon': 11,
#   '-four one teaspoon zero point five zero point five peck grams one': 12,
#   '-four ounces eight ounces eight ounces zero point seven five sixteen ounces': 13,
#   '-four ounces four one one zero point five teaspoons zero point one two five teaspoons one six ounces two ounces zero point two five': 14,
#   'nine inches two joule ells zero point five one centavo year roentgen short tons': 851,
#   'nine inches two one peck grams one pint': 852,
#   'nine inches two one zero point five one tablespoon one teaspoon zero point two five one one six ounces': 853,
#   'nine inches two one zero point five teaspoons one zero point five teaspoons zero point five teaspoons zero point seven five teaspoons': 854,
#   'nine inches two tablespoons zero point two five teaspoons one two one zero point five teaspoons zero point two five teaspoons two zero point five': 855,
#   'nine inches two zero point five one tablespoon zero point two five teaspoons one teaspoon one four': 856,
#   'nine inches zero point five cups zero point five cups zero point five cups two one cup one teaspoon': 857,
#   'nine inches zero point five one tablespoon one one tablespoon three one teaspoon one': 858,
#   'nine inches zero point seven five zero point three three three three three three three three three three three three three three three three zero point two five teaspoons one teaspoon zero point two five three four five one tablespoon one': 859,
#   'nine inches zero point seven five zero point two five zero point two five teaspoons zero point two five teaspoons zero point two five teaspoons three one': 860,
#   'nine inches zero point three three three three three three three three three three three three three three three three zero point five one one teaspoon three one': 861,
#   'nine ounces one peck grams zero point six six six six six six six six six six six six six six six six one': 862,
#   'nine ounces one six ounces one zero point five teaspoons two nine inches': 863,
#   'nine ounces one zero point five one zero point five one teaspoon one teaspoon': 864,
#   'nine ounces two sixteen ounces zero point seven five one ten point seven five ounces zero point one two five teaspoons one two point eight ounces': 865,
#   'nine ounces two tablespoons three one pound zero point two five inches four two two tablespoons two one tablespoon two zero point two five': 866,
#   'nine ounces zero point two five cups one tablespoon one teaspoon one two dozens': 867,
#   'nine pounds': 868,
#   'nine quarts two one one teaspoon zero point five one teaspoon': 869,
#   'nine three tablespoons three three five teaspoons': 870,
#   'nine zero point five one tablespoon one pint zero point five minutes of arc minute of arc zero point two five pounds': 871,
#   'nine zero point five zero point five two tablespoons two tablespoons three zero point five pints': 872,
#   'nineteen point eight ounces twenty-one point five ounces zero point seven five two twelve ounces zero point two five one fourteen ounces one teaspoon': 873,
#   'nineteen point eight ounces zero point five one one twelve ounces six one point four ounces': 874,
#   'one': 875,
#   'one centavo year roentgen short tons one peck grams one one one one eight ounces eight ounces': 876,
#   'one centavo year roentgen short tons one ten': 877,
#   'one centavo year south african rand short tons one centavo year south african rand short tons zero point five peck grams one one three': 878,
#   'one cup one cup one ounce': 879,
#   'one cup one cup zero point three three three three three three three three three three three three three three three three cups three tablespoons zero point five teaspoons zero point two five teaspoons one teaspoon zero point five teaspoons zero point five teaspoons two cups one cup zero point five cups zero point five teaspoons zero point two five cups zero point two five cups': 880,
#   'one cup one four point five ounces one two pounds two cups one': 881,
#   'one cup one one zero point five cups': 882,
#   'one cup zero point five cups eight ounces one cup one cup two zero point three three three three three three three three three three three three three three three three cups two cups two tablespoons': 883,
#   'one dozen one one one one zero point seven five zero point five pounds': 884,
#   'one dozen one one two seven ounces one one one pound': 885,
#   'one dozen one ten point seven five ounces ninety-seven percentages two one one eight ten ounces one pound': 886,
#   'one eight one one': 887,
#   'one eight ounces': 888,
#   'one eight ounces eight': 889,
#   'one eight ounces ninety-eight percentages zero point two five one point five one teaspoon zero point five teaspoons': 890,
#   'one eight ounces one': 891,
#   'one four one sixteen ounces two teaspoons two teaspoons one teaspoon zero point six six six six six six six six six six six six six six six six zero point five teaspoons zero point five teaspoons three point five': 983,
#   'one four one tablespoon four point five ounces one': 984,
#   'one four one teaspoon one': 985,
#   'one four one teaspoon one sixteen ounces one one tablespoon one': 986,
#   'one four one teaspoon zero point five one zero point seven five one': 987,
#   'one four one three one tablespoon': 988,
#   'one four one zero point five one three ounces': 989,
#   'one four one zero point five zero point two five teaspoons zero point two five': 990,
#   'one four one zero point seven five': 991,
#   'one four ounces four tablespoons one': 992,
#   'one four ounces one eight ounces one eight ounces one one twelve ounces': 993,
#   'one four ounces one eight ounces one twelve ounces': 994,
#   'one four ounces one four ounces one two': 995,
#   'one four ounces one one point five two one two fifteen ounces one teaspoon': 996,
#   'one four ounces three tablespoons three tablespoons one zero point three three three three three three three three three three three three three three three three zero point two five zero point five teaspoons zero point two five teaspoons': 997,
#   'one four ounces zero point three three three three three three three three three three three three three three three three four two one zero point two five teaspoons zero point one two five teaspoons': 998,
#   'one four peck grams four': 999,
#   'one four peck grams two four': 1000,
#   ...},
#  {'bake': 1,
#   'blend': 2,
#   'boil': 3,
#   'chop': 4,
#   'cook': 5,
#   'dice': 6,
#   'fry': 7,
#   'grill': 8,
#   'mince': 9,
#   'mix': 10,
#   'roast': 11,
#   'saute': 12,
#   'season': 13,
#   'serve': 14,
#   'slice': 15,
#   'stir': 16,
#   'whisk': 17})

# %% [markdown]
# # **Annotate Data with Cuisines and Dietary Tags**

# %%
# Load the data with state IDs
data = pd.read_csv("/content/drive/MyDrive/FlavorFlow/Data/states_micro_data.csv")

# Expanded keyword-based rules for cuisine tagging
cuisine_keywords = {
    "Italian": ["spaghetti", "pasta", "marinara", "mozzarella", "risotto", "parmesan", "basil", "gnocchi", "focaccia"],
    "Mexican": ["taco", "quesadilla", "guacamole", "salsa", "enchilada", "jalapeno", "chipotle", "mole", "tamale"],
    "Indian": ["curry", "masala", "paneer", "tandoori", "naan", "dal", "biryani", "samosa", "chutney", "ghee"],
    "Chinese": ["soy sauce", "noodles", "dumpling", "fried rice", "tofu", "szechuan", "hoisin", "wonton", "dim sum"],
    "French": ["baguette", "croissant", "ratatouille", "brie", "crepes", "coq au vin", "bouillabaisse", "quiche"],
    "Japanese": ["sushi", "sashimi", "miso", "udon", "ramen", "teriyaki", "wasabi", "tempura", "matcha", "yakitori"],
    "Thai": ["coconut milk", "lemongrass", "curry paste", "pad thai", "tom yum", "fish sauce", "basil", "sticky rice"],
    "Greek": ["feta", "tzatziki", "gyro", "souvlaki", "moussaka", "olives", "spanakopita", "dolma", "baklava"],
    "Middle Eastern": ["hummus", "falafel", "shawarma", "tahini", "sumac", "pita", "za'atar", "labneh", "tabbouleh"],
    "Spanish": ["paella", "tapas", "chorizo", "gazpacho", "saffron", "manchego", "tortilla", "jamón", "patatas bravas"],
    "Korean": ["kimchi", "bulgogi", "gochujang", "bibimbap", "kimbap", "doenjang", "samgyeopsal", "japchae", "soju"],
    "Vietnamese": ["pho", "banh mi", "spring roll", "nuoc cham", "fish sauce", "lemongrass", "rice paper", "vermicelli"],
    "Caribbean": ["jerk", "plantain", "callaloo", "ackee", "curry goat", "rum", "coconut", "conch", "pigeon peas"],
    "Ethiopian": ["injera", "doro wat", "berbere", "shiro", "kitfo", "niter kibbeh", "teff", "lentils", "collard greens"],
    "Moroccan": ["couscous", "tagine", "harissa", "ras el hanout", "preserved lemon", "mint tea", "saffron", "dates"],
    "Turkish": ["kebab", "baklava", "lokum", "borek", "simit", "manti", "hummus", "dolma", "raki", "yogurt"],
    "Brazilian": ["feijoada", "pão de queijo", "brigadeiro", "açai", "chimichurri", "tapioca", "farofa", "guarana"],
    "Filipino": ["adobo", "sinigang", "lumpia", "halo-halo", "lechon", "pandesal", "tocino", "kare-kare", "balut"],
    "Russian": ["borscht", "pelmeni", "blini", "kvass", "beetroot", "smetana", "pirozhki", "caviar", "vodka"],
    "German": ["bratwurst", "sauerkraut", "pretzel", "schnitzel", "spätzle", "strudel", "bier", "mustard"],
    "African": ["jollof rice", "fufu", "egusi", "koki", "bunny chow", "sosatie", "couscous", "baobab", "grilled fish"],
    "American": ["burger", "hot dog", "BBQ", "mac and cheese", "fried chicken", "apple pie", "pancakes", "cornbread"],
    "British": ["fish and chips", "shepherd's pie", "yorkshire pudding", "scones", "bangers and mash", "custard"],
    "Australian": ["vegemite", "lamington", "barbie", "pavlova", "meat pie", "tim tam", "kangaroo", "anzac biscuit"]
}

# Expanded keyword-based rules for dietary tagging
dietary_keywords = {
    "Vegan": ["tofu", "tempeh", "seitan", "plant-based", "vegan", "nutritional yeast", "jackfruit", "lentils"],
    "Vegetarian": ["cheese", "egg", "paneer", "vegetarian", "yogurt", "butter", "honey", "milk"],
    "Gluten-Free": ["gluten-free", "quinoa", "rice", "cornmeal", "almond flour", "buckwheat", "sorghum", "tapioca"],
    "Keto": ["avocado", "bacon", "cheese", "almond flour", "low-carb", "butter", "cream", "olive oil", "zucchini"],
    "Paleo": ["grass-fed", "wild-caught", "almond flour", "coconut", "honey", "sweet potato", "ghee", "bone broth"],
    "Low-FODMAP": ["zucchini", "carrot", "banana", "potato", "quinoa", "cucumber", "spinach", "blueberries"],
    "Pescatarian": ["salmon", "tuna", "shrimp", "mackerel", "fish", "seafood", "sardines", "trout"],
    "Nut-Free": ["nut-free", "seed", "sunflower butter", "sesame", "pumpkin seeds", "nut allergy"],
    "Dairy-Free": ["dairy-free", "almond milk", "coconut milk", "oat milk", "lactose-free", "soy milk"],
    "Soy-Free": ["soy-free", "coconut aminos", "sunflower oil", "ghee", "olive oil", "fish oil"],
    "Whole30": ["whole30", "cauliflower rice", "coconut oil", "avocado oil", "zoodles", "compliant", "dates"],
    "Halal": ["halal", "zabiha", "permissible", "no pork", "no alcohol"],
    "Kosher": ["kosher", "pareve", "no shellfish", "no pork", "kosher salt", "matzo"]
}

# Function to tag cuisine based on keywords
def tag_cuisine(ingredients_text):
    # Check if ingredients_text is a string, otherwise use an empty string
    ingredients_text = ingredients_text if isinstance(ingredients_text, str) else ""
    for cuisine, keywords in cuisine_keywords.items():
        if any(keyword.lower() in ingredients_text.lower() for keyword in keywords):
            return cuisine
    return "Other"

# Function to tag dietary information based on keywords
def tag_dietary(ingredients_text):
    # Check if ingredients_text is a string, otherwise use an empty string
    ingredients_text = ingredients_text if isinstance(ingredients_text, str) else ""
    tags = []
    for diet, keywords in dietary_keywords.items():
        if any(keyword.lower() in ingredients_text.lower() for keyword in keywords):
            tags.append(diet)
    return tags if tags else ["None"]

# Apply the tagging functions to the data
data['cuisine'] = data['ingredients'].apply(tag_cuisine)
data['dietary_tags'] = data['ingredients'].apply(tag_dietary)


# Manual Verification: Extract a sample for verification
sample_data = data.sample(10)  # Adjust the sample size as needed for verification

# Save the annotated data
data.to_csv("/content/drive/MyDrive/FlavorFlow/Data/annotated_micro_data.csv", index=False)

# Display the sample data for manual verification
sample_data
# Out:
#       Unnamed: 0                                title  \
# 3995        3995               Baking Powder Pancakes
# 6788        6788                     Strawberry Bread
# 4767        4767        Aunty Ann'S Vegetable Chowder
# 3235        3235                Peanut Butter Bonbons
# 8861        8861                Ground Beef Casserole
# 1809        1809       Chicken And Dressing Casserole
# 2102        2102            Momma'S Forgotten Cookies
# 3867        3867  Grilled Coriander Pepper Pork Chops
# 9776        9776            Meringues Or "Forgettums"
# 4136        4136               One Pot Ham-N-Potatoes
#
#                                             ingredients  \
# 3995  one point five one teaspoon three tablespoons ...
# 6788  three one teaspoon one teaspoon zero point fiv...
# 4767  one one one one zero point five pounds six six...
# 3235  one pound two two pounds three teaspoons one p...
# 8861  one peck grams zero point five pounds one one ...
# 1809              one pound one one one two tablespoons
# 2102  two zero point seven five one teaspoon six ounces
# 3867  two one tablespoon one tablespoon one tablespo...
# 9776  two zero point six six six six six six six six...
# 4136  one sixteen ounces one tablespoon one six poin...
#
#                                              directions  \
# 3995  [ `` Mix flour , salt , sugar and baking powde...
# 6788  [ `` Sift dry ingredients into a large bowl an...
# 4767  [ `` In a five-quart Dutch oven , heat 3 table...
# 3235  [ `` Mix together the margarine , peanut butte...
# 8861  [ `` Cook and drain noodles . `` , `` Brown me...
# 1809  [ `` Combine Stove Top seasoning packet , both...
# 2102  [ `` Preheat oven to 375\u00b0 . `` , `` Beat ...
# 3867  [ `` Heat outdoor grill . Combine all ingredie...
# 9776  [ `` Use any combination of the nuts , coconut...
# 4136  [ `` Combine potatoes , seasoning mix , milk ,...
#
#                                                  link    source  \
# 3995  www.cookbooks.com/Recipe-Details.aspx?id=795622  Gathered
# 6788  www.cookbooks.com/Recipe-Details.aspx?id=738821  Gathered
# 4767  www.cookbooks.com/Recipe-Details.aspx?id=705402  Gathered
# 3235  www.cookbooks.com/Recipe-Details.aspx?id=747577  Gathered
# 8861  www.cookbooks.com/Recipe-Details.aspx?id=784615  Gathered
# 1809  www.cookbooks.com/Recipe-Details.aspx?id=113195  Gathered
# 2102  www.cookbooks.com/Recipe-Details.aspx?id=974078  Gathered
# 3867   www.cookbooks.com/Recipe-Details.aspx?id=99558  Gathered
# 9776  www.cookbooks.com/Recipe-Details.aspx?id=168385  Gathered
# 4136   www.cookbooks.com/Recipe-Details.aspx?id=84834  Gathered
#
#                                                     NER  \
# 3995  ["flour", "salt", "sugar", "baking powder", "e...
# 6788  ["flour", "soda", "salt", "cinnamon", "sugar",...
# 4767  ["onion", "celery", "garlic", "tomatoes", "car...
# 3235  ["margarine", "peanut butter", "powdered sugar...
# 8861  ["noodles", "cheese", "mushroom soup", "milk",...
# 1809  ["chicken breasts", "Stove Top chicken", "crea...
# 2102  ["egg whites", "sugar", "vanilla", "salt", "ch...
# 3867  ["garlic", "coriander seed", "ground black pep...
# 9776  ["egg whites", "salt", "sugar", "vanilla", "nu...
# 4136  ["green beans", "butter", "ham", "water", "red...
#
#                                   ingredients_tokenized  \
# 3995  [{'quantity': None, 'unit': 'one', 'ingredient...
# 6788  [{'quantity': None, 'unit': 'three', 'ingredie...
# 4767  [{'quantity': None, 'unit': 'one', 'ingredient...
# 3235  [{'quantity': None, 'unit': 'one', 'ingredient...
# 8861  [{'quantity': None, 'unit': 'one', 'ingredient...
# 1809  [{'quantity': None, 'unit': 'one', 'ingredient...
# 2102  [{'quantity': None, 'unit': 'two', 'ingredient...
# 3867  [{'quantity': None, 'unit': 'two', 'ingredient...
# 9776  [{'quantity': None, 'unit': 'two', 'ingredient...
# 4136  [{'quantity': None, 'unit': 'one', 'ingredient...
#
#                                    directions_tokenized ingredient_states  \
# 3995  {'actions': ['mix'], 'related_ingredients': ['...            [3934]
# 6788  {'actions': ['bake', 'mix', 'stir'], 'related_...            [2342]
# 4767  {'actions': ['saute', 'cook'], 'related_ingred...            [1355]
# 3235  {'actions': ['mix'], 'related_ingredients': ['...            [5878]
# 8861  {'actions': ['cook'], 'related_ingredients': [...            [3576]
# 1809  {'actions': ['bake', 'stir'], 'related_ingredi...            [5546]
# 2102  {'actions': [], 'related_ingredients': ['[', '...            [9178]
# 3867  {'actions': ['grill'], 'related_ingredients': ...            [2235]
# 9776  {'actions': [], 'related_ingredients': ['[', '...            [9286]
# 4136  {'actions': ['mix', 'stir'], 'related_ingredie...            [6757]
#
#      action_states cuisine dietary_tags
# 3995          [10]   Other       [None]
# 6788   [1, 10, 16]   Other       [None]
# 4767       [12, 5]   Other       [None]
# 3235          [10]   Other       [None]
# 8861           [5]   Other       [None]
# 1809       [1, 16]   Other       [None]
# 2102            []   Other       [None]
# 3867           [8]   Other       [None]
# 9776            []   Other       [None]
# 4136      [10, 16]   Other       [None]

# %% [markdown]
# # **DataFrame Creation**
#
# Data Structure:
# - recipe_id: Unique identifier for each recipe.
# - ingredient: The name of the ingredient used in the recipe.
# - quantity: The amount of the ingredient, converted to a standard format.
# - unit: The unit of measurement for the ingredient.
# - step: List of actions associated with the recipe (e.g., chop, mix, bake).
# - cuisine: The cuisine classification of the recipe (e.g., Italian, Chinese).
# - nutrition: Placeholder for nutritional information (if available).
# - tags: List of dietary tags associated with the recipe (e.g., Vegan, Gluten-Free).
#
# Processing Assumptions:
# - Quantities are converted to numeric values and missing quantities are set to 0.
# - Units are standardized to a consistent format for modeling.
# - Nutrition information is currently unavailable and marked as 'unknown'.
# - Missing values in ingredients, units, or nutrition fields are handled appropriately.

# %%
# Load the annotated data
data = pd.read_csv("/content/drive/MyDrive/FlavorFlow/Data/annotated_micro_data.csv")

# Step 1: Structure Data in a DataFrame
# Extract unique recipe IDs
data['recipe_id'] = data.index + 1  # Assign unique IDs based on the index

# Split ingredients into separate components
structured_data = []

for idx, row in data.iterrows():
    ingredients_list = eval(row['ingredients_tokenized'])  # Convert string to list of dicts
    steps_list = eval(row['directions_tokenized'])  # Convert string to dict
    for ingredient in ingredients_list:
        structured_data.append({
            'recipe_id': row['recipe_id'],
            'ingredient': ingredient['ingredient'],
            'quantity': ingredient['quantity'],
            'unit': ingredient['unit'],
            'step': steps_list['actions'],
            'cuisine': row['cuisine'],
            'nutrition': None,  # Placeholder for nutrition info if available
            'tags': row['dietary_tags']
        })

# Create a structured DataFrame
df = pd.DataFrame(structured_data)

# Step 2: Data Quality Checks
# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)

# Fill missing values or handle them appropriately
df['quantity'].fillna(0, inplace=True)  # Assuming 0 for missing quantities
df['unit'].fillna("unknown", inplace=True)  # Placeholder for unknown units
df['nutrition'].fillna("unknown", inplace=True)  # Placeholder for missing nutrition info

# Check for outliers in 'quantity'
df['quantity'] = pd.to_numeric(df['quantity'], errors='coerce')  # Convert to numeric
outliers = df[(df['quantity'] < 0) | (df['quantity'] > 1000)]  # Example check for outliers
print("Outliers:\n", outliers)

# Standardize units (if not done earlier)
# Example: Converting 'tablespoon' to 'tbsp' or 'grams' to 'g'
df['unit'] = df['unit'].replace({
    'tablespoon': 'tbsp',
    'teaspoon': 'tsp',
    'kilogram': 'kg',
    'liter': 'l',
    'ounce': 'oz',
    # Add more conversions as needed
})

# Step 3: Save Data
# Export cleaned and structured data to a .csv file
df.to_csv("/content/drive/MyDrive/FlavorFlow/Data/structured_micro_data.csv", index=False)

# Display the first few rows of the structured DataFrame
df.head()
# Out:
# Missing Values:
#  recipe_id        0
# ingredient       0
# quantity      9932
# unit            30
# step             0
# cuisine          0
# nutrition     9932
# tags             0
# dtype: int64
# Outliers:
#  Empty DataFrame
# Columns: [recipe_id, ingredient, quantity, unit, step, cuisine, nutrition, tags]
# Index: []
# <ipython-input-25-e37966af9613>:35: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['quantity'].fillna(0, inplace=True)  # Assuming 0 for missing quantities
# <ipython-input-25-e37966af9613>:35: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['quantity'].fillna(0, inplace=True)  # Assuming 0 for missing quantities
# <ipython-input-25-e37966af9613>:36: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['unit'].fillna("unknown", inplace=True)  # Placeholder for unknown units
# <ipython-input-25-e37966af9613>:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['nutrition'].fillna("unknown", inplace=True)  # Placeholder for missing nutrition info
#    recipe_id                                         ingredient  quantity  \
# 0          1  zero point five zero point five teaspoons zero...         0
# 1          2      four one one centavo year roentgen short tons         0
# 2          3  sixteen ounces one eight ounces zero point thr...         0
# 3          4  two ten point five ounces one ten point five o...         0
# 4          5  zero point seven five one one pound three poin...         0
#
#   unit               step cuisine nutrition      tags
# 0  one  [boil, mix, stir]   Other   unknown  ['None']
# 1  one        [bake, mix]   Other   unknown  ['None']
# 2  two       [stir, cook]   Other   unknown  ['None']
# 3  one       [bake, boil]   Other   unknown  ['None']
# 4  one                 []   Other   unknown  ['None']
